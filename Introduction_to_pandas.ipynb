# %%
import pandas as pd

# %% [markdown]
# Creating multiple dictionaries and storing them in a list

# %%
data = [
        {'name':'Alex','age':20,'salary':1050},
        {'name':'Bob','age':52,'salary':1400},
        {'name':'Cat','age':23,'salary': 1690}
]
df = pd.DataFrame(data, columns=['name','age','salary'])
print(df)
# Out:
#    name  age  salary
# 0  Alex   20    1050
# 1   Bob   52    1400
# 2   Cat   23    1690

# %% [markdown]
# Creating multiple lists and storing them in a list

# %%
data = [
        ['Alex',20,1050],
        ['Bob', 52,1400],
        ['Cat',23,1690]
]
df = pd.DataFrame(data,columns=['name','age','salary'])
print(df)
# Out:
#    name  age  salary
# 0  Alex   20    1050
# 1   Bob   52    1400
# 2   Cat   23    1690

# %% [markdown]
# Import csv files onto google colab

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bc1e8489-1ff0-41e9-b8ba-61ad65029a62" name="files[]" multiple disabled />
#      <output id="result-bc1e8489-1ff0-41e9-b8ba-61ad65029a62">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving unit05-data.csv to unit05-data.csv

# %%
df = pd.read_csv('unit05-data.csv')

# %% [markdown]
# Using sum()

# %%
sg = df[(df['country']=='Singapore')]
sg['Estimated incidence (all forms) per 100 000 population'].sum()
# Out:
# 700.0

# %% [markdown]
# To extract a row, we use **loc()** function with the desired index we want

# %%
print(df.loc[0])
# Out:
# country                                                   Afghanistan
# iso2                                                               AF
# iso3                                                              AFG
# Region Code                                                       EMR
# year                                                             2000
# Total Population                                             20093756
# Estimated incidence (all forms) per 100 000 population            190
# Name: 0, dtype: object

# %% [markdown]
# **Grouping and Aggregation in Pandas**

# %%
student =['Anna','Bob','Cass','Darius','Eugene','Felica','Gordon']
classroom =['A','A','B','A','B','B','B']
age = [15,15,16,17,15,18,15]
score =[80,82,95,70,67,98,85]
data={"Student":student,"Class":classroom,"Age": age,"Score":score}
df = pd.DataFrame(data)
df
# Out:
#   Student Class  Age  Score
# 0    Anna     A   15     80
# 1     Bob     A   15     82
# 2    Cass     B   16     95
# 3  Darius     A   17     70
# 4  Eugene     B   15     67
# 5  Felica     B   18     98
# 6  Gordon     B   15     85

# %%
class_score = df.groupby(['Class','Age']).agg({'Score':['mean','min','max']})
class_score
# Out:
#           Score
#            mean min max
# Class Age
# A     15     81  80  82
#       17     70  70  70
# B     15     76  67  85
#       16     95  95  95
#       18     98  98  98

# %% [markdown]
# **Select rows**

# %%
df = pd.read_csv('unit05-data.csv')
year_2002 = df[(df['year']==2002)]
year_2002
# Out:
#                         country  ... Estimated incidence (all forms) per 100 000 population
# 2                   Afghanistan  ...                                              189.0
# 19                      Albania  ...                                               22.0
# 36                      Algeria  ...                                               74.0
# 53               American Samoa  ...                                                3.9
# 70                      Andorra  ...                                                8.2
# ...                         ...  ...                                                ...
# 3568  Wallis and Futuna Islands  ...                                              149.0
# 3585   West Bank and Gaza Strip  ...                                                1.9
# 3602                      Yemen  ...                                              102.0
# 3619                     Zambia  ...                                              695.0
# 3636                   Zimbabwe  ...                                              617.0
#
# [213 rows x 7 columns]

# %% [markdown]
# **Select rows whose column value is not NA/NAN**

# %%
df_not_null = df[df.year.notnull()]
df_not_null
# Out:
#           country  ... Estimated incidence (all forms) per 100 000 population
# 0     Afghanistan  ...                                              190.0
# 1     Afghanistan  ...                                              189.0
# 2     Afghanistan  ...                                              189.0
# 3     Afghanistan  ...                                              189.0
# 4     Afghanistan  ...                                              189.0
# ...           ...  ...                                                ...
# 3646     Zimbabwe  ...                                              355.0
# 3647     Zimbabwe  ...                                              304.0
# 3648     Zimbabwe  ...                                              278.0
# 3649     Zimbabwe  ...                                              242.0
# 3650     Zimbabwe  ...                                              208.0
#
# [3651 rows x 7 columns]

# %% [markdown]
# **Pandas isin()**

# %%
years = [2002,2008]
selection = df[df.year.isin(years)]
selection
# Out:
#           country  ... Estimated incidence (all forms) per 100 000 population
# 2     Afghanistan  ...                                              189.0
# 8     Afghanistan  ...                                              189.0
# 19        Albania  ...                                               22.0
# 25        Albania  ...                                               16.0
# 36        Algeria  ...                                               74.0
# ...           ...  ...                                                ...
# 3608        Yemen  ...                                               60.0
# 3619       Zambia  ...                                              695.0
# 3625       Zambia  ...                                              534.0
# 3636     Zimbabwe  ...                                              617.0
# 3642     Zimbabwe  ...                                              487.0
#
# [427 rows x 7 columns]

# %% [markdown]
# **Negation symbol (~)**

# %% [markdown]
# Get rows where the year is not 2002 nor 2008

# %%
select_negation = df[~df.year.isin(years)]
select_negation
# Out:
#           country  ... Estimated incidence (all forms) per 100 000 population
# 0     Afghanistan  ...                                              190.0
# 1     Afghanistan  ...                                              189.0
# 3     Afghanistan  ...                                              189.0
# 4     Afghanistan  ...                                              189.0
# 5     Afghanistan  ...                                              189.0
# ...           ...  ...                                                ...
# 3646     Zimbabwe  ...                                              355.0
# 3647     Zimbabwe  ...                                              304.0
# 3648     Zimbabwe  ...                                              278.0
# 3649     Zimbabwe  ...                                              242.0
# 3650     Zimbabwe  ...                                              208.0
#
# [3224 rows x 7 columns]

# %% [markdown]
# **Select rows using multiple conditions**

# %%
country = ["Singapore"]

# %%
selection = df[df.year.isin(years) & df.country.isin(country)]
selection
# Out:
#         country  ... Estimated incidence (all forms) per 100 000 population
# 2894  Singapore  ...                                               42.0
# 2900  Singapore  ...                                               37.0
#
# [2 rows x 7 columns]

# %% [markdown]
# **Concatenate by row and column**

# %%
student1 =['Anna','Bob','Cass','Darius','Eugene','Felica','Gordon']
classroom1 =['A','A','B','A','B','B','B']
age1 = [15,15,16,17,15,18,15]
score1 =[80,82,95,70,67,98,85]
data1={"Student":student,"Class":classroom,"Age": age,"Score":score}
df1 = pd.DataFrame(data1)

student2 =["Charlie","James","Ethan"]
classroom2 =['C', 'C','C']
score2 = [95,77,80]
age2 = [16,17,18]
data2 = {"Student":student2,"Class":classroom2,"Age":age2,"Score": score2}
df2 = pd.DataFrame(data2)

# %%
df_row = pd.concat([df1,df2],ignore_index=True)
df_row
# Out:
#    Student Class  Age  Score
# 0     Anna     A   15     80
# 1      Bob     A   15     82
# 2     Cass     B   16     95
# 3   Darius     A   17     70
# 4   Eugene     B   15     67
# 5   Felica     B   18     98
# 6   Gordon     B   15     85
# 7  Charlie     C   16     95
# 8    James     C   17     77
# 9    Ethan     C   18     80

# %% [markdown]
# **Merge DataFrames on Specific Keys**

# %% [markdown]
# when: how = 'right'

# %%
student3 =['Anna','Bob','Cass','Darius','Eugene','Felica','Gordon','Emma']
id3=[1,2,3,4,5,6,7,9]
data3 ={"Student":student3,"id":id3}
df3 = pd.DataFrame(data3,columns=['Student','id'])
df_merge_col = pd.merge(df1,df3,on="Student",how='right')
df_merge_col
# Out:
#   Student Class   Age  Score  id
# 0    Anna     A  15.0   80.0   1
# 1     Bob     A  15.0   82.0   2
# 2    Cass     B  16.0   95.0   3
# 3  Darius     A  17.0   70.0   4
# 4  Eugene     B  15.0   67.0   5
# 5  Felica     B  18.0   98.0   6
# 6  Gordon     B  15.0   85.0   7
# 7    Emma   NaN   NaN    NaN   9

# %% [markdown]
# when: how = 'left'

# %%
student3 =['Anna','Bob','Cass','Darius','Eugene','Felica','Gordon','Emma']
id3=[1,2,3,4,5,6,7,9]
data3 ={"Student":student3,"id":id3}
df3 = pd.DataFrame(data3,columns=['Student','id'])
df_merge_col = pd.merge(df1,df3,on="Student",how='left')
df_merge_col
# Out:
#   Student Class  Age  Score  id
# 0    Anna     A   15     80   1
# 1     Bob     A   15     82   2
# 2    Cass     B   16     95   3
# 3  Darius     A   17     70   4
# 4  Eugene     B   15     67   5
# 5  Felica     B   18     98   6
# 6  Gordon     B   15     85   7

# %% [markdown]
# **Pivot tables**

# %% [markdown]
# aggfunc is np.mean by default, which calculates the average

# %%
df_merge_col.pivot_table(index="Class",columns="Age", values="Score")
# Out:
# Age      15    16    17    18
# Class
# A      81.0   NaN  70.0   NaN
# B      76.0  95.0   NaN  98.0

# %% [markdown]
# **Set missing value to 0**

# %%
df_merge_col.pivot_table(index="Class",columns="Age", values="Score",fill_value = 0)
# Out:
# Age    15  16  17  18
# Class
# A      81   0  70   0
# B      76  95   0  98

# %%
df_merge_col.pivot_table(index="Class",columns="Age", values="Score",aggfunc='min')
# Out:
# Age      15    16    17    18
# Class
# A      80.0   NaN  70.0   NaN
# B      67.0  95.0   NaN  98.0

# %% [markdown]
# **Output into a .csv file**

# %%
df_merge_col.to_csv(r'df_merge_col.csv',index= False, header= True)

# %% [markdown]
# **Missing data**

# %% [markdown]
# axis = 0 : remove row
#
# axis = 1 : remove column

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ddc2e5c1-27a1-466d-a7a5-39a6f1b5f30c" name="files[]" multiple disabled />
#      <output id="result-ddc2e5c1-27a1-466d-a7a5-39a6f1b5f30c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving MissingData.xls to MissingData.xls

# %% [markdown]
# *remove row*

# %%
df = pd.read_excel("MissingData.xls",typ ="series")
df = df.dropna() 
df
# Out:
#     0 First Name  Last Name  Gender        Country   Age        Date    Id
# 0   1      Dulce      Abril  Female  United States  32.0  15/10/2017  1562
# 1   2       Mara  Hashimoto  Female  Great Britain  25.0  16/08/2016  1582
# 5   6     Gaston      Brumm    Male  United States  24.0  21/05/2015  2554
# 6   7       Etta       Hurn  Female  Great Britain  56.0  15/10/2017  3598
# 7   8    Earlean     Melgar  Female  United States  27.0  16/08/2016  2456
# 8   9   Vincenza    Weiland  Female  United States  40.0  21/05/2015  6548
# 9  10     Fallon    Winward  Female  Great Britain  28.0  16/08/2016  5486

# %% [markdown]
# *remove column*

# %%
df = pd.read_excel("MissingData.xls",typ ="series")
df = df.dropna(axis=1) 
df
# Out:
#     0 First Name  Last Name  Gender        Country        Date    Id
# 0   1      Dulce      Abril  Female  United States  15/10/2017  1562
# 1   2       Mara  Hashimoto  Female  Great Britain  16/08/2016  1582
# 2   3     Philip       Gent    Male         France  21/05/2015  2587
# 3   4   Kathleen     Hanner  Female  United States  15/10/2017  3549
# 4   5    Nereida    Magwood  Female  United States  16/08/2016  2468
# 5   6     Gaston      Brumm    Male  United States  21/05/2015  2554
# 6   7       Etta       Hurn  Female  Great Britain  15/10/2017  3598
# 7   8    Earlean     Melgar  Female  United States  16/08/2016  2456
# 8   9   Vincenza    Weiland  Female  United States  21/05/2015  6548
# 9  10     Fallon    Winward  Female  Great Britain  16/08/2016  5486

# %% [markdown]
# **Imputation**
#
# Fill the missing values by some other values

# %%
df = pd.read_excel("MissingData.xls",typ ="series")
df['Age']=df['Age'].fillna(0)
df
# Out:
#     0 First Name  Last Name  Gender        Country   Age        Date    Id
# 0   1      Dulce      Abril  Female  United States  32.0  15/10/2017  1562
# 1   2       Mara  Hashimoto  Female  Great Britain  25.0  16/08/2016  1582
# 2   3     Philip       Gent    Male         France   0.0  21/05/2015  2587
# 3   4   Kathleen     Hanner  Female  United States   0.0  15/10/2017  3549
# 4   5    Nereida    Magwood  Female  United States   0.0  16/08/2016  2468
# 5   6     Gaston      Brumm    Male  United States  24.0  21/05/2015  2554
# 6   7       Etta       Hurn  Female  Great Britain  56.0  15/10/2017  3598
# 7   8    Earlean     Melgar  Female  United States  27.0  16/08/2016  2456
# 8   9   Vincenza    Weiland  Female  United States  40.0  21/05/2015  6548
# 9  10     Fallon    Winward  Female  Great Britain  28.0  16/08/2016  5486

# %% [markdown]
# # Data Visualisation in Python

# %% [markdown]
# install plotly

# %%
# !pip install plotly
import plotly.express as px
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (4.4.1)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly) (1.12.0)

# %% [markdown]
# **Plotting histogram**

# %%
x = [84,65,78,75,89,59,90,88,83,72,91,90,73,54]
df = pd.DataFrame(x,columns=["x"])
data = px.histogram(df,x="x")
data
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="080dc3df-db40-495c-97af-f503da235e0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("080dc3df-db40-495c-97af-f503da235e0e")) {
#                     Plotly.newPlot(
#                         '080dc3df-db40-495c-97af-f503da235e0e',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{x}<br>count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "histogram", "x": [84, 65, 78, 75, 89, 59, 90, 88, 83, 72, 91, 90, 73, 54], "xaxis": "x", "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %% [markdown]
# **Plotting boxplot**

# %%
x = [84,65,78,75,89,59,90,88,83,72,91,90,73,54]
df = pd.DataFrame(x,columns=['x'])
boxplot = px.box(df,y='x')
boxplot
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c4012a88-3bcb-478e-b7f4-1886b59f2e9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c4012a88-3bcb-478e-b7f4-1886b59f2e9e")) {
#                     Plotly.newPlot(
#                         'c4012a88-3bcb-478e-b7f4-1886b59f2e9e',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "x=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x0": " ", "xaxis": "x", "y": [84, 65, 78, 75, 89, 59, 90, 88, 83, 72, 91, 90, 73, 54], "y0": " ", "yaxis": "y"}],
#                         {"boxmode": "group", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}},  ...

# %% [markdown]
# **Plotting Bar Graph**

# %%
foodItemList =['sushi','pizza','hamburger','fried chicken']
numberList = [ 2,5,4,3]
df = pd.DataFrame({"Food Item":foodItemList,"Number of students":numberList})
data = px.bar(df,x="Food Item",y="Number of students")
data
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0b9399e9-26f2-415a-8afc-0de7e205b46d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0b9399e9-26f2-415a-8afc-0de7e205b46d")) {
#                     Plotly.newPlot(
#                         '0b9399e9-26f2-415a-8afc-0de7e205b46d',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Food Item=%{x}<br>Number of students=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["sushi", "pizza", "hamburger", "fried chicken"], "xaxis": "x", "y": [2, 5, 4, 3], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""} ...

# %% [markdown]
# **Plotting Pie Chart**

# %%
chart = px.pie(df,values="Number of students",names="Food Item")
chart
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8c53c4d7-8d6d-4fcc-816d-7655735e4050" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8c53c4d7-8d6d-4fcc-816d-7655735e4050")) {
#                     Plotly.newPlot(
#                         '8c53c4d7-8d6d-4fcc-816d-7655735e4050',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "Food Item=%{label}<br>Number of students=%{value}", "labels": ["sushi", "pizza", "hamburger", "fried chicken"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [2, 5, 4, 3]}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %% [markdown]
# **Reading JSON in Pandas**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8bdb70ff-4da5-42a9-8452-b7c82107995c" name="files[]" multiple disabled />
#      <output id="result-8bdb70ff-4da5-42a9-8452-b7c82107995c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving example_1.json to example_1.json

# %%
df = pd.read_json('example_1.json',typ='series')
df
# Out:
# fruit    Apple
# size     Large
# color      Red
# dtype: object

# %% [markdown]
# **Reading XML Files Using Python**

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2aa9a653-46e6-473a-b054-574c3682f7ee" name="files[]" multiple disabled />
#      <output id="result-2aa9a653-46e6-473a-b054-574c3682f7ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Unit 05 - XML Sample Data.xml to Unit 05 - XML Sample Data.xml

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('Unit 05 - XML Sample Data.xml')
root = tree.getroot()
for child in root:
  print(child.tag,child.attrib)
# Out:
# country {'name': 'Liechtenstein'}
# country {'name': 'Singapore'}
# country {'name': 'Panama'}
